# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt #시각화 패키지
import seaborn as sns #시각화 패키지
plt.style.use('fivethirtyeight') # 테마바꾸기
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

data=pd.read_csv('./SeoulBikeData.csv', engine='python', encoding='CP949')
data.head() # data 확인
# Out:
#          Date  Rented Bike Count  Hour  Temperature(ºC)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(ºC)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# 1                      0.0           0.0            0.0  Winter  No Holiday
# 2                      0.0           0.0            0.0  Winter  No Holiday
# 3                      0.0           0.0            0.0  Winter  No Holiday
# 4                      0.0           0.0            0.0  Winter  No Holiday
#
#   Functioning Day
# 0             Yes
# 1             Yes
# 2             Yes
# 3             Yes
# 4             Yes

# %%
data.isnull().sum() # 전체 결측치 확인
# Out:
# Date                         0
# Rented Bike Count            0
# Hour                         0
# Temperature(ºC)              0
# Humidity(%)                  0
# Wind speed (m/s)             0
# Visibility (10m)             0
# Dew point temperature(ºC)    0
# Solar Radiation (MJ/m2)      0
# Rainfall(mm)                 0
# Snowfall (cm)                0
# Seasons                      0
# Holiday                      0
# Functioning Day              0
# dtype: int64

# %%
data.describe()
# Out:
#        Rented Bike Count         Hour  Temperature(ºC)  Humidity(%)  \
# count        8760.000000  8760.000000      8760.000000  8760.000000
# mean          704.602055    11.500000        12.882922    58.226256
# std           644.997468     6.922582        11.944825    20.362413
# min             0.000000     0.000000       -17.800000     0.000000
# 25%           191.000000     5.750000         3.500000    42.000000
# 50%           504.500000    11.500000        13.700000    57.000000
# 75%          1065.250000    17.250000        22.500000    74.000000
# max          3556.000000    23.000000        39.400000    98.000000
#
#        Wind speed (m/s)  Visibility (10m)  Dew point temperature(ºC)  \
# count       8760.000000       8760.000000                8760.000000
# mean           1.724909       1436.825799                   4.073813
# std            1.036300        608.298712                  13.060369
# min            0.000000         27.000000                 -30.600000
# 25%            0.900000        940.000000                  -4.700000
# 50%            1.500000       1698.000000                   5.100000
# 75%            2.300000       2000.000000                  14.800000
# max            7.400000       2000.000000                  27.200000
#
#        Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)
# count              8760.000000   8760.000000    8760.000000
# mean                  0.569111      0.148687       0.075068
# std                   0.868746      1.128193       0.436746
# min                   0.000000      0.000000       0.000000
# 25%                   0.000000      0.000000       0.000000
# 50%                   0.010000      0.000000       0.000000
# 75%                   0.930000      0.000000       0.000000
# max                   3.520000     35.000000       8.800000

# %%
data['Functioning Day'].replace(['Yes','No'],[0,1],inplace=True)
data=data.loc[data['Functioning Day']==0]
data.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(ºC)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(ºC)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# 1                      0.0           0.0            0.0  Winter  No Holiday
# 2                      0.0           0.0            0.0  Winter  No Holiday
# 3                      0.0           0.0            0.0  Winter  No Holiday
# 4                      0.0           0.0            0.0  Winter  No Holiday
#
#    Functioning Day
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
data.drop("Functioning Day",axis=1,inplace=True)

# %%
data.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(ºC)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(ºC)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday
# 0                      0.0           0.0            0.0  Winter  No Holiday
# 1                      0.0           0.0            0.0  Winter  No Holiday
# 2                      0.0           0.0            0.0  Winter  No Holiday
# 3                      0.0           0.0            0.0  Winter  No Holiday
# 4                      0.0           0.0            0.0  Winter  No Holiday

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) 

fig=plt.gcf() # fig에 접근
fig.set_size_inches(10,8) # fig그림 크기 조절
plt.show()

# %%
data.drop("Date",axis=1,inplace=True)
data1 = pd.get_dummies(data)
data1.drop("Holiday_Holiday",axis=1,inplace=True)

sns.heatmap(data1.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) 

fig=plt.gcf() # fig에 접근
fig.set_size_inches(10,8) # fig그림 크기 조절
plt.show()

# %%
data['Seasons'].replace(['Spring','Summer','Autumn','Winter'],[1,2,3,4],inplace=True)
data['Holiday'].replace(['No Holiday','Holiday'],[0,1],inplace=True)

data.head()
# Out:
#    Rented Bike Count  Hour  Temperature(ºC)  Humidity(%)  Wind speed (m/s)  \
# 0                254     0             -5.2           37               2.2
# 1                204     1             -5.5           38               0.8
# 2                173     2             -6.0           39               1.0
# 3                107     3             -6.2           40               0.9
# 4                 78     4             -6.0           36               2.3
#
#    Visibility (10m)  Dew point temperature(ºC)  Solar Radiation (MJ/m2)  \
# 0              2000                      -17.6                      0.0
# 1              2000                      -17.6                      0.0
# 2              2000                      -17.7                      0.0
# 3              2000                      -17.6                      0.0
# 4              2000                      -18.6                      0.0
#
#    Rainfall(mm)  Snowfall (cm)  Seasons  Holiday
# 0           0.0            0.0        4        0
# 1           0.0            0.0        4        0
# 2           0.0            0.0        4        0
# 3           0.0            0.0        4        0
# 4           0.0            0.0        4        0

# %%
data.describe()
# Out:
#        Rented Bike Count         Hour  Temperature(ºC)  Humidity(%)  \
# count        8465.000000  8465.000000      8465.000000  8465.000000
# mean          729.156999    11.507029        12.771057    58.147194
# std           642.351166     6.920899        12.104375    20.484839
# min             2.000000     0.000000       -17.800000     0.000000
# 25%           214.000000     6.000000         3.000000    42.000000
# 50%           542.000000    12.000000        13.500000    57.000000
# 75%          1084.000000    18.000000        22.700000    74.000000
# max          3556.000000    23.000000        39.400000    98.000000
#
#        Wind speed (m/s)  Visibility (10m)  Dew point temperature(ºC)  \
# count       8465.000000       8465.000000                8465.000000
# mean           1.725883       1433.873479                   3.944997
# std            1.034281        609.051229                  13.242399
# min            0.000000         27.000000                 -30.600000
# 25%            0.900000        935.000000                  -5.100000
# 50%            1.500000       1690.000000                   4.700000
# 75%            2.300000       2000.000000                  15.200000
# max            7.400000       2000.000000                  27.200000
#
#        Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)      Seasons  \
# count              8465.000000    8465.00000    8465.000000  8465.000000
# mean                  0.567868       0.14912       0.077685     2.483993
# std                   0.868245       1.12554       0.444063     1.127194
# min                   0.000000       0.00000       0.000000     1.000000
# 25%                   0.000000       0.00000       0.000000     1.000000
# 50%                   0.010000       0.00000       0.000000     2.000000
# 75%                   0.930000       0.00000       0.000000     4.000000
# max                   3.520000      35.00000       8.800000     4.000000
#
#            Holiday
# count  8465.000000
# mean      0.048198
# std       0.214198
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000
